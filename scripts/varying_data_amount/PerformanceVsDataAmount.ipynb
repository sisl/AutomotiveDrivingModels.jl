# %%
include("notebook_input.jl")
dfs = load_data()
# Out:
# WARNING: redefining constant RESULTS_DIR
# WARNING: redefining constant DASH_TYPES
# Dict{AbstractString,DataFrames.DataFrame} with 6 entries:
#   "Static Gaussian"  => 11x12 DataFrames.DataFrame…
#   "Random Forest"    => 8x12 DataFrames.DataFrame…
#   "Linear Bayesian"  => 8x12 DataFrames.DataFrame…
#   "Linear Gaussian"  => 8x12 DataFrames.DataFrame…
#   "Dynamic Forest"   => 8x12 DataFrames.DataFrame…
#   "Bayesian Network" => 8x12 DataFrames.DataFrame…

# %%
include("notebook_input.jl")
targets = names(dfs["Static Gaussian"])[5:end]
@manipulate for target in targets
    plot_target_vs_data_amount(dfs, target)
end
# Out:
# Interact.Options{:ToggleButtons,Symbol}(Signal{Symbol}(logl_train, nactions=0),"target",:logl_train,"logl_train",Interact.OptionDict(Any["logl_train","logl_test","rwse_speed_test","rwse_dcl_test","rwse_headway_test","smooth_sumsquare","smooth_autocor","smooth_jerkinvs"],Dict{Any,Any}("rwse_dcl_test"=>:rwse_dcl_test,"smooth_jerkinvs"=>:smooth_jerkinvs,"smooth_sumsquare"=>:smooth_sumsquare,"rwse_headway_test"=>:rwse_headway_test,"logl_test"=>:logl_test,"rwse_speed_test"=>:rwse_speed_test,"smooth_autocor"=>:smooth_autocor,"logl_train"=>:logl_train)),Any[],Any[])
# WARNING: redefining constant RESULTS_DIR
# WARNING: redefining constant DASH_TYPES
# PGFPlots.Axis(PGFPlots.Plots.Plot[PGFPlots.Plots.Linear(2x11 Array{Real,2}:
#  0.001    0.00199526  0.00398107  0.00794328  …  0.251189  0.501187  1.0
#  3.78787  3.55453     3.44842     3.53781        3.40194   3.34616   3.36056,"none",nothing,"thick, color=black!40, solid",nothing,nothing),PGFPlots.Plots.Linear(2x8 Array{Real,2}:
# ...
